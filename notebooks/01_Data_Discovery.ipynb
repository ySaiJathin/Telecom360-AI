# %% [markdown]
# # Telecom360 AI
#
# ## Sprint 1 - Data Discovery
#
# ### Objective
# Understand the IBM Telco Customer Churn dataset before preprocessing and model development.
#
# ### Business problem
# The Telecom company wants to identify customers who are likely to churn and understand the factors contributing to churn.
#
# ### Expected Outcome
# - Understand the data structure.
# - Identify the target variable.
# - Identify feature types.
# - Detect missing values and data quality issues.
#
# ### Enginnering Notes
# This notebook performs dataset discovery only.
# No preprocessing.
# No model training.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.shape
# Out:
# (7043, 33)

# %% [markdown]
# ### Observation
#
# - The dataset contains **7,043 customer records** and **33 columns**.
# - The dataset size is suitable for analysis using Pandas.
# - No distributed processing framework is required.

# %%
df.columns.tolist()
# Out:
# ['CustomerID',
#  'Count',
#  'Country',
#  'State',
#  'City',
#  'Zip Code',
#  'Lat Long',
#  'Latitude',
#  'Longitude',
#  'Gender',
#  'Senior Citizen',
#  'Partner',
#  'Dependents',
#  'Tenure Months',
#  'Phone Service',
#  'Multiple Lines',
#  'Internet Service',
#  'Online Security',
#  'Online Backup',
#  'Device Protection',
#  'Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Contract',
#  'Paperless Billing',
#  'Payment Method',
#  'Monthly Charges',
#  'Total Charges',
#  'Churn Label',
#  'Churn Value',
#  'Churn Score',
#  'CLTV',
#  'Churn Reason']

# %% [markdown]
# ### Observation
#
# - The dataset contains customer demographic information, service subscriptions, billing details, geographic information, CLTV, and churn-related variables.
#
# - The dataset also includes several columns that may cause target leakage and will require further investigation.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
# ...

# %%
df.head(10)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
# 5  4190-MFLUW      1  United States  California  Los Angeles     90020
# 6  8779-QRDMV      1  United States  California  Los Angeles     90022
# 7  1066-JKSGK      1  United States  California  Los Angeles     90024
# 8  6467-CHFZW      1  United States  California  Los Angeles     90028
# 9  8665-UTDHZ      1  United States  California  Los Angeles     90029
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# ...

# %% [markdown]
# ### Observation
#
# - Most columns contain complete information.
# - `Churn Reason` contains missing values, which appear to be business-driven.
# - `Total Charges` is stored as a string and requires further investigation.

# %% [markdown]
# ## Initial Findings
#
# - Dataset contains 7043 customer records.
# - No Sigificant missing values except Churn Reason.
# - Missing values in Churn Reason appear business-driven.
# - Total Charges is stored as text and requires investigation.
# - Dataset includes customer location features.
# - Dataset includes CLTV, enabling customer prioritization.
# - Target leakage columns identified:
#     - Churn Label
#     - Churn Value
#     - Churn Score
#     - Churn Reason

# %% [markdown]
# # Investigating Data Quality
#
# ## Investigating the Count Column

# %%
df['Count'].value_counts()
# Out:
# Count
# 1    7043
# Name: count, dtype: int64

# %% [markdown]
# ### Observation
#
# Every record contains the value **1**.
#
# The column has no variation and therefore provides no predictive value.
#
# It will be removed during preprocessing.

# %% [markdown]
# ## Investigating the Total Charges Column

# %%
df[df['Total Charges'].str.strip()=='']
# Out:
#       CustomerID  Count        Country       State            City  Zip Code  \
# 2234  4472-LVYGI      1  United States  California  San Bernardino     92408
# 2438  3115-CZMZD      1  United States  California    Independence     93526
# 2568  5709-LVOEQ      1  United States  California       San Mateo     94401
# 2667  4367-NUYAO      1  United States  California       Cupertino     95014
# 2856  1371-DWPAZ      1  United States  California        Redcrest     95569
# 4331  7644-OMVMY      1  United States  California     Los Angeles     90029
# 4687  3213-VVOLG      1  United States  California        Sun City     92585
# 5104  2520-SGTTA      1  United States  California      Ben Lomond     95005
# 5719  2923-ARZLG      1  United States  California        La Verne     91750
# 6772  4075-WKNIU      1  United States  California            Bell     90201
# 6840  2775-SEFEE      1  United States  California      Wilmington     90744
#
# ...

# %% [markdown]
# ### Observation
#
# A total of **11 records** contain blank values in `Total Charges`.
#
# These blank values explain why Pandas imported the column as a string.
#
# The issue will be handled during Sprint 3 (Data Preprocessing).

# %%
data_dictionary=pd.DataFrame({
    "Column": df.columns,
    "Data Type": df.dtypes.astype(str)
})
data_dictionary
# Out:
#                               Column Data Type
# CustomerID                CustomerID       str
# Count                          Count     int64
# Country                      Country       str
# State                          State       str
# City                            City       str
# Zip Code                    Zip Code     int64
# Lat Long                    Lat Long       str
# Latitude                    Latitude   float64
# Longitude                  Longitude   float64
# Gender                        Gender       str
# Senior Citizen        Senior Citizen       str
# Partner                      Partner       str
# Dependents                Dependents       str
# Tenure Months          Tenure Months     int64
# Phone Service          Phone Service       str
# Multiple Lines        Multiple Lines       str
# Internet Service    Internet Service       str
# Online Security      Online Security       str
# Online Backup          Online Backup       str
# ...

# %% [markdown]
# ### Data Dictionary Notes
#
# The initial data dictionary has been generated to document every feature in the dataset.
#
# During preprocessing, each column will be classified as:
#
# - Feature
# - Target
# - Identifier
# - Metadata
# - Target Leakage
#
# This documentation will guide feature selection before model training.

# %% [markdown]
# # Sprint 1 Summary
#
# ## Completed
#
# - Loaded the dataset successfully.
# - Explored dataset dimensions.
# - Reviewed all dataset columns.
# - Examined data types.
# - Identified missing values.
# - Investigated data quality issues.
# - Generated the initial data dictionary.
#
# ## Key Findings
#
# - Dataset contains **7,043 telecom customers**.
# - `CustomerID` is the unique identifier.
# - `Churn Value` will be used as the target variable.
# - `Count` provides no predictive value.
# - `Total Charges` contains 11 blank records.
# - `Churn Label`, `Churn Score`, and `Churn Reason` represent target leakage.
# - `CLTV` can be used for customer prioritization.
